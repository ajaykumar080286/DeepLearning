# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/DeepLearning/blob/master/29_Keras_Tuner_Hyperparameter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import tensorflow
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
df=pd.read_csv("https://raw.githubusercontent.com/ajaykumar080286/DeepLearning/master/diabetes_1.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.corr()["Outcome"]  #to check which coloumn is useful ,we can ignore unused column
# Out:
# Pregnancies                 0.221898
# Glucose                     0.466581
# BloodPressure               0.065068
# SkinThickness               0.074752
# Insulin                     0.130548
# BMI                         0.292695
# DiabetesPedigreeFunction    0.173844
# Age                         0.238356
# Outcome                     1.000000
# Name: Outcome, dtype: float64

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
scale=StandardScaler()
X=scale.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=1)

# %%
model=Sequential()
model.add(Dense(32,activation="relu", input_dim=8))
model.add(Dense(1,activation="sigmoid"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 321 (1.25 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.fit(X_train,y_train,batch_size=32,epochs=100, validation_data=(X_test,y_test))
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6384 - loss: 0.6680 - val_accuracy: 0.6688 - val_loss: 0.6729
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6971 - loss: 0.6256 - val_accuracy: 0.7338 - val_loss: 0.6327
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7117 - loss: 0.5947 - val_accuracy: 0.7792 - val_loss: 0.6008
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7231 - loss: 0.5685 - val_accuracy: 0.7987 - val_loss: 0.5753
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7296 - loss: 0.5471 - val_accuracy: 0.7987 - val_loss: 0.5589
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7443 - loss: 0.5300 - val_accuracy: 0.7922 - val_loss: 0.5433
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7557 - loss: 0.5162 - val_accuracy: 0.7857 - val_loss: 0.5314
# Epoch 8/100
# ...

# %%
#.How to select Appropriate Optimizer
#No of Nodes In a layers
# how to select no of Hidden layers
#All in one

# %% [markdown]
# **#.How to select Appropriate Optimizer**

# %%
#pip install -U keras.tuner

# %%
import keras_tuner as kt

# %%
def build_model(hp):

  model=Sequential()
  model.add(Dense(32,activation="relu", input_dim=8))
  model.add(Dense(1,activation="sigmoid"))

  optimizer=hp.Choice("optimizer", values=["adam","sgd","rmsprop","Adagrad"])

  model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )
  return model

# %%
tuner = kt.RandomSearch(
    hypermodel=build_model,
    objective="val_accuracy",
    max_trials=5
)

# %%
tuner.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# Trial 4 Complete [00h 00m 02s]
# val_accuracy: 0.7792207598686218
#
# Best val_accuracy So Far: 0.8181818127632141
# Total elapsed time: 00h 00m 08s

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 1
# optimizer (Choice)
# {'default': 'adam', 'conditions': [], 'values': ['adam', 'sgd', 'rmsprop', 'Adagrad'], 'ordered': False}

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 2 summary
# Hyperparameters:
# optimizer: rmsprop
# Score: 0.8181818127632141
#
# Trial 3 summary
# Hyperparameters:
# optimizer: adam
# Score: 0.7792207598686218
#
# Trial 0 summary
# Hyperparameters:
# optimizer: sgd
# Score: 0.6688311696052551
#
# Trial 1 summary
# Hyperparameters:
# optimizer: Adagrad
# Score: 0.3311688303947449

# %%
best_hps = tuner.get_best_hyperparameters()[0].values

# %%
best_hps
# Out:
# {'optimizer': 'rmsprop'}

# %%
model=tuner.get_best_models(num_models=1)[0]
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 6 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 321 (1.25 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train,y_train,batch_size=32,epochs=100,initial_epoch=6, validation_data=(X_test,y_test))
# Out:
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7573 - loss: 0.4977 - val_accuracy: 0.8117 - val_loss: 0.4844
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7752 - loss: 0.4860 - val_accuracy: 0.8052 - val_loss: 0.4787
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7785 - loss: 0.4794 - val_accuracy: 0.7857 - val_loss: 0.4748
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7818 - loss: 0.4744 - val_accuracy: 0.7792 - val_loss: 0.4728
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7752 - loss: 0.4702 - val_accuracy: 0.7792 - val_loss: 0.4713
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7801 - loss: 0.4677 - val_accuracy: 0.7792 - val_loss: 0.4696
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7801 - loss: 0.4645 - val_accuracy: 0.7857 - val_loss: 0.4682
# Epoch 14/100
# ...

# %%
def build_model1(hp):
    model = keras.Sequential()

    units=hp.Int("units",min_value=8, max_value=128, step=32)
    model.add(Dense(units=units, activation="relu",input_dim=8))
    model.add(Dense(1,activation="sigmoid"))

    model.compile(optimizer="rmsprop",loss="binary_crossentropy", metrics=["accuracy"])

    return model

# %%
tuner1 = kt.RandomSearch(
    hypermodel=build_model1,
    objective="val_accuracy",
    max_trials=5, directory="mydir"
)

# %%
tuner1.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# Trial 4 Complete [00h 00m 02s]
# val_accuracy: 0.7857142686843872
#
# Best val_accuracy So Far: 0.8181818127632141
# Total elapsed time: 00h 00m 09s

# %%
tuner1.search_space_summary()
# Out:
# Search space summary
# Default search space size: 1
# units (Int)
# {'default': None, 'conditions': [], 'min_value': 8, 'max_value': 128, 'step': 32, 'sampling': 'linear'}

# %%
tuner1.results_summary()
# Out:
# Results summary
# Results in mydir/untitled_project
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0 summary
# Hyperparameters:
# units: 40
# Score: 0.8181818127632141
#
# Trial 1 summary
# Hyperparameters:
# units: 72
# Score: 0.7857142686843872
#
# Trial 3 summary
# Hyperparameters:
# units: 104
# Score: 0.7857142686843872
#
# Trial 2 summary
# Hyperparameters:
# units: 8
# Score: 0.7077922224998474

# %%
best_hps = tuner1.get_best_hyperparameters()[0].values

# %%
best_hps
# Out:
# {'units': 40}

# %%
model=tuner1.get_best_models(num_models=1)[0]

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 40)             │           360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            41 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 401 (1.57 KB)
#  Trainable params: 401 (1.57 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train,y_train,batch_size=32,epochs=100,initial_epoch=6, validation_data=(X_test,y_test))
# Out:
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.7655 - loss: 0.4947 - val_accuracy: 0.8312 - val_loss: 0.4897
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7720 - loss: 0.4820 - val_accuracy: 0.8182 - val_loss: 0.4822
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7736 - loss: 0.4748 - val_accuracy: 0.8117 - val_loss: 0.4773
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7785 - loss: 0.4692 - val_accuracy: 0.8117 - val_loss: 0.4739
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7818 - loss: 0.4651 - val_accuracy: 0.8182 - val_loss: 0.4716
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7752 - loss: 0.4623 - val_accuracy: 0.8117 - val_loss: 0.4707
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7801 - loss: 0.4593 - val_accuracy: 0.7987 - val_loss: 0.4698
# Epoch 14/100
# ...

# %%
def build_model2(hp):

  model=Sequential()
  model.add(Dense(40,activation="relu", input_dim=8))
  for i in range(hp.Int("num_layers", 1, 10)):
    model.add(Dense(40,activation="relu"))

  model.add(Dense(1,activation="sigmoid"))
  model.compile(optimizer="rmsprop",loss="binary_crossentropy", metrics=["accuracy"])

  return model

# %%
tuner2 = kt.RandomSearch(
    hypermodel=build_model2,
    objective="val_accuracy",
    max_trials=5,directory="mydir1"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tuner2.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# Trial 5 Complete [00h 00m 04s]
# val_accuracy: 0.8116883039474487
#
# Best val_accuracy So Far: 0.8116883039474487
# Total elapsed time: 00h 00m 16s

# %%
tuner2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 1
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 10, 'step': 1, 'sampling': 'linear'}

# %%
tuner2.results_summary()
# Out:
# Results summary
# Results in mydir1/untitled_project
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 4 summary
# Hyperparameters:
# num_layers: 7
# Score: 0.8116883039474487
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 2
# Score: 0.8051947951316833
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 10
# Score: 0.798701286315918
#
# Trial 2 summary
# Hyperparameters:
# num_layers: 5
# Score: 0.7922077775001526
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 4
# Score: 0.7792207598686218

# %%
best_hps = tuner2.get_best_hyperparameters()[0].values

# %%
best_hps
# Out:
# {'num_layers': 7}

# %%
model=tuner2.get_best_models(num_models=1)[0]
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 2 variables whereas the saved optimizer has 20 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 40)             │           360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 40)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 40)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 40)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 40)             │         1,640 │
# ...

# %%
model.fit(X_train,y_train,batch_size=32,epochs=100,initial_epoch=6, validation_data=(X_test,y_test))
# Out:
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.6948 - val_loss: 2.0777
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9984 - loss: 0.0115 - val_accuracy: 0.7013 - val_loss: 2.6491
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.0916 - val_accuracy: 0.6948 - val_loss: 2.0969
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.6818 - val_loss: 2.1609
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.7013 - val_loss: 2.2966
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9853 - loss: 0.0638 - val_accuracy: 0.7078 - val_loss: 2.1885
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9870 - loss: 0.0383 - val_accuracy: 0.6948 - val_loss: 2.0078
# Epoch 14/100
# ...

# %%
def build_model(hp):
    model = Sequential()

    counter=0

    for i in range(hp.Int("num_layers", min_value=1, max_value=10)):

      if counter==0:

        model.add(
            Dense(
                # Tune number of units separately.
                units=hp.Int("units"+str(i), min_value=32, max_value=512, step=32),
                activation=hp.Choice("activation"+str(i), ["relu", "tanh","sigmoid"]),
                input_dim=8
            )
        )
      else:

          model.add(
            Dense(
                # Tune number of units separately.
                units=hp.Int("units"+str(i), min_value=32, max_value=512, step=32),
                activation=hp.Choice("activation"+str(i), ["relu", "tanh","sigmoid"])
            )
        )
    counter+=1

    model.add(Dense(1,activation="sigmoid"))
    optimizer=hp.Choice("optimizer", values=["adam","sgd","rmsprop","Adagrad"])
    model.compile(
        optimizer=optimizer,
        loss="binary_crossentropy",
        metrics=["accuracy"],
    )

    return model

# %%
tuner2 = kt.RandomSearch(
    hypermodel=build_model,
    objective="val_accuracy",
    max_trials=5,directory="mydir2"
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
tuner2.search(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
# Out:
# Trial 5 Complete [00h 00m 04s]
# val_accuracy: 0.6428571343421936
#
# Best val_accuracy So Far: 0.8181818127632141
# Total elapsed time: 00h 00m 17s

# %%
tuner2.search_space_summary()
# Out:
# Search space summary
# Default search space size: 22
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 10, 'step': 1, 'sampling': 'linear'}
# units0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# activation0 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh', 'sigmoid'], 'ordered': False}
# optimizer (Choice)
# {'default': 'adam', 'conditions': [], 'values': ['adam', 'sgd', 'rmsprop', 'Adagrad'], 'ordered': False}
# units1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# activation1 (Choice)
# {'default': 'relu', 'conditions': [], 'values': ['relu', 'tanh', 'sigmoid'], 'ordered': False}
# units2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# activation2 (Choice)
# ...

# %%
tuner2.results_summary()
# Out:
# Results summary
# Results in mydir2/untitled_project
# Showing 10 best trials
# Objective(name="val_accuracy", direction="max")
#
# Trial 0 summary
# Hyperparameters:
# num_layers: 1
# units0: 224
# activation0: tanh
# optimizer: sgd
# Score: 0.8181818127632141
#
# Trial 1 summary
# Hyperparameters:
# num_layers: 10
# units0: 416
# activation0: relu
# optimizer: rmsprop
# units1: 32
# activation1: relu
# units2: 32
# activation2: relu
# units3: 32
# activation3: relu
# units4: 32
# activation4: relu
# units5: 32
# activation5: relu
# units6: 32
# activation6: relu
# units7: 32
# activation7: relu
# units8: 32
# activation8: relu
# units9: 32
# activation9: relu
# Score: 0.8181818127632141
#
# Trial 3 summary
# Hyperparameters:
# num_layers: 5
# units0: 192
# activation0: relu
# optimizer: rmsprop
# units1: 352
# activation1: relu
# units2: 224
# activation2: tanh
# units3: 320
# activation3: sigmoid
# units4: 192
# activation4: sigmoid
# units5: 512
# activation5: tanh
# units6: 512
# ...

# %%
best_hps = tuner2.get_best_hyperparameters()[0].values

# %%
best_hps
# Out:
# {'num_layers': 1, 'units0': 224, 'activation0': 'tanh', 'optimizer': 'sgd'}

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 40)             │           360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 40)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 40)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 40)             │         1,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 40)             │         1,640 │
# ...

# %%
model.fit(X_train,y_train,batch_size=32,epochs=100,initial_epoch=6, validation_data=(X_test,y_test))
# Out:
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 1.0000 - loss: 7.9811e-05 - val_accuracy: 0.7078 - val_loss: 2.9685
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 6.0029e-05 - val_accuracy: 0.7078 - val_loss: 3.0319
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 3.8044e-05 - val_accuracy: 0.7143 - val_loss: 3.1662
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9951 - loss: 0.0090 - val_accuracy: 0.7338 - val_loss: 3.1273
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9967 - loss: 0.0110 - val_accuracy: 0.7338 - val_loss: 2.8715
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 8.6944e-05 - val_accuracy: 0.7143 - val_loss: 2.9945
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 5.7483e-05 - val_accuracy: 0.7208 - val_loss: 3.0273
# Epoch 14/100
# ...
