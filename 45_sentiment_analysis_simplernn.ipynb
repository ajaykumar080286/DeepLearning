# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/DeepLearning/blob/master/45_sentiment_analysis_simplernn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN,Embedding,Flatten

from keras.datasets import imdb
from keras.utils import pad_sequences

# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
tokenizer.word_index
# Out:
# {'india': 1,
#  'jeetega': 2,
#  'hip': 3,
#  'ki': 4,
#  'jai': 5,
#  'kohli': 6,
#  'sachin': 7,
#  'dhoni': 8,
#  'go': 9,
#  'hurray': 10,
#  'bhai': 11,
#  'bharat': 12,
#  'mata': 13,
#  'modi': 14,
#  'ji': 15,
#  'inquilab': 16,
#  'zindabad': 17}

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
model = Sequential()
model.add(Embedding(len(tokenizer.word_index)+1,output_dim=2, input_shape=(5,)))
model.summary()
# Out:
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_17 (Embedding)        │ (None, 5, 2)           │            36 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 36 (144.00 B)
#  Trainable params: 36 (144.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# [[[-0.03862767 -0.01795621]
#   [-0.04438429 -0.00720716]
#   [ 0.01532289  0.03401113]
#   [ 0.01532289  0.03401113]
#   [ 0.01532289  0.03401113]]
#
#  [[-0.04438429 -0.00720716]
#   [-0.04438429 -0.00720716]
#   [ 0.01532289  0.03401113]
#   [ 0.01532289  0.03401113]
#   [ 0.01532289  0.03401113]]
#
#  [[ 0.03821895 -0.02650234]
#   [ 0.03821895 -0.02650234]
#   [-0.00673363 -0.00902077]
#   [ 0.01532289  0.03401113]
#   [ 0.01532289  0.03401113]]
#
#  [[-0.01417103 -0.02829416]
#   [ 0.01519778 -0.02941347]
#   [-0.01417103 -0.02829416]
#   [-0.04438429 -0.00720716]
#   [-0.01417103 -0.02829416]]
#
#  [[-0.01882175  0.03556219]
#   [-0.01320332 -0.03867743]
#   [-0.04510247  0.04062252]
#   [-0.03989594 -0.00082402]
#   [ 0.01532289  0.03401113]]
#
#  [[-0.03107106  0.01697303]
#   [-0.03107106  0.01697303]
#   [ 0.01532289  0.03401113]
#   [ 0.01532289  0.03401113]
#   [ 0.01532289  0.03401113]]
#
#  [[ 0.02768171 -0.03583614]
# ...

# %% [markdown]
# **Embedding**

# %%
(X_train,y_train),(X_test,y_test) = imdb.load_data(num_words=10000)

# %%
X_train = pad_sequences(X_train,padding='post',maxlen=50,dtype='int32')
X_test = pad_sequences(X_test,padding='post',maxlen=50,dtype='int32')

# %%
X_train.shape
# Out:
# (25000, 50)

# %%
model = Sequential()
model.add(Input(shape=(50,))) # Explicitly define input shape to match padded sequences
model.add(Embedding(100001, output_dim=2)) # Increased input_dim to accommodate larger IMDb vocabulary
model.add(SimpleRNN(32, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_18 (Embedding)        │ (None, 50, 2)          │       200,002 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_13 (SimpleRNN)       │ (None, 32)             │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 201,155 (785.76 KB)
#  Trainable params: 201,155 (785.76 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs=1, validation_data=(X_test, y_test))
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 17s 19ms/step - accuracy: 0.6380 - loss: 0.6074 - val_accuracy: 0.7736 - val_loss: 0.4798
